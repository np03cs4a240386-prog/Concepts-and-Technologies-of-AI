# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cs4a240386-prog/Concepts-and-Technologies-of-AI/blob/main/Worksheet5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1.

# %%
data = pd.read_csv("/content/drive/MyDrive/AI Workshop/student.csv")

# %%
data.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
data.tail()
# Out:
#      Math  Reading  Writing
# 995    72       74       70
# 996    73       86       90
# 997    89       87       94
# 998    83       82       78
# 999    66       66       72

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Math     1000 non-null   int64
#  1   Reading  1000 non-null   int64
#  2   Writing  1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB

# %%
data.describe()
# Out:
#               Math      Reading      Writing
# count  1000.000000  1000.000000  1000.000000
# mean     67.290000    69.872000    68.616000
# std      15.085008    14.657027    15.241287
# min      13.000000    19.000000    14.000000
# 25%      58.000000    60.750000    58.000000
# 50%      68.000000    70.000000    69.500000
# 75%      78.000000    81.000000    79.000000
# max     100.000000   100.000000   100.000000

# %%
X = data[['Math', 'Reading']].values
Y = data['Writing'].values

# %% [markdown]
# 2.

# %%
X_matrix = X.T
Y_vector = Y

# %% [markdown]
# 3.

# %%
def train_test_split_scratch(X, Y, test_size=0.2, random_seed=42):
    np.random.seed(random_seed)
    indices = np.arange(len(X))
    np.random.shuffle(indices)

    split = int(len(X) * (1 - test_size))
    train_idx = indices[:split]
    test_idx = indices[split:]

    return X[train_idx], X[test_idx], Y[train_idx], Y[test_idx]

# %%
X_train, X_test, Y_train, Y_test = train_test_split_scratch(X, Y)

# %% [markdown]
# 4

# %%
def cost_function(X, Y, W):
    n = len(Y)
    Y_pred = np.dot(X, W)
    cost = (1 / (2 * n)) * np.sum((Y_pred - Y) ** 2)
    return cost

# %% [markdown]
# 5.

# %%
X_test_case = np.array([[1, 2], [3, 4], [5, 6]])
Y_test_case = np.array([3, 7, 11])
W_test_case = np.array([1, 1])

cost = cost_function(X_test_case, Y_test_case, W_test_case)
print("Cost:", cost)
# Out:
# Cost: 0.0

# %% [markdown]
# 6.

# %%
def gradient_descent(X, Y, W, alpha, iterations):
    cost_history = []
    m = len(Y)

    for _ in range(iterations):
        Y_pred = np.dot(X, W)
        loss = Y_pred - Y
        dw = (1 / m) * np.dot(X.T, loss)
        W = W - alpha * dw
        cost = cost_function(X, Y, W)
        cost_history.append(cost)

    return W, cost_history

# %% [markdown]
# 7.

# %%
np.random.seed(0)
X_rand = np.random.rand(100, 3)
Y_rand = np.random.rand(100)
W_rand = np.random.rand(3)

final_params, cost_hist = gradient_descent(X_rand, Y_rand, W_rand, 0.01, 1000)
print("Final Parameters:", final_params)
# Out:
# Final Parameters: [0.20551667 0.54295081 0.10388027]

# %% [markdown]
# 8.

# %%
def rmse(Y, Y_pred):
    return np.sqrt(np.mean((Y - Y_pred) ** 2))

# %% [markdown]
# 9.

# %%
def r2(Y, Y_pred):
    mean_y = np.mean(Y)
    ss_tot = np.sum((Y - mean_y) ** 2)
    ss_res = np.sum((Y - Y_pred) ** 2)
    return 1 - (ss_res / ss_tot)

# %% [markdown]
# 10.

# %%
def main():
    data = pd.read_csv("/content/drive/MyDrive/AI Workshop/student.csv")

    X = data[['Math', 'Reading']].values
    Y = data['Writing'].values

    X_train, X_test, Y_train, Y_test = train_test_split_scratch(X, Y)

    W = np.zeros(X_train.shape[1])
    alpha = 0.00001
    iterations = 1000

    W_opt, cost_history = gradient_descent(X_train, Y_train, W, alpha, iterations)

    Y_pred = np.dot(X_test, W_opt)

    print("Final Weights:", W_opt)
    print("RMSE:", rmse(Y_test, Y_pred))
    print("R2 Score:", r2(Y_test, Y_pred))

# %%
main()
# Out:
# Final Weights: [0.3533225  0.64122757]
# RMSE: 5.258385317376058
# R2 Score: 0.8688492410749991

# %% [markdown]
# 11.

# %% [markdown]
# 1. The model performance is acceptable as RMSE is low and R² is close to 1.
# 2. Very high learning rate caused divergence.
# 3. Very small learning rate slowed convergence.
# 4. Optimal learning rate balances speed and stability.
